# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
model = ChatOllama(model="gpt-oss:120b-cloud")

template1 = PromptTemplate.from_template(
    template = "Write a detailed report on the {topic}",
)

template2 = PromptTemplate.from_template(
    template = "Write a 5 line summary on the folloeing {text}"
)

parser = StrOutputParser()

chain = template1 | model | parser | template2 | model | parser

response = chain.invoke({"topic":"MCP servers"})
print(response)
# Out:
# Failed to multipart ingest runs: Connection error caused failure to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. Please confirm your internet connection. SSLError(MaxRetryError("HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Max retries exceeded with url: /runs/multipart (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))"))
# Content-Length: 6950
# API Key: lsv2_********************************************7ftrace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2; trace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef1-0e31-7cf1-b699-7f7482d76adf; trace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef1-0e32-7fd2-adb3-58d85124c9b8
# - MCP servers are protocol‑agnostic middleware that decouple producers and consumers, enforce security/QoS policies, and support exactly‑once delivery at scales from a single node to >10 M msgs / sec in active‑active, geo‑distributed clusters.
# - The architecture consists of an ingress engine, routing processor, transformation layer, durable Raft‑replicated journal, delivery engine, and extensible security plug‑ins, all managed via a web UI/CLI and observable through Prometheus, OpenTelemetry, and immutable audit logs.
# - Leading implementations include OpenMCP (Apache 2.0, Go/Rust, K8s‑native), IBM MCP (Java/Spring, enterprise HA), MCP‑X (C++, ultra‑low‑latency), Azure MCP Service (SaaS), and MCP‑Edge (Eclipse, IoT‑optimized).
# - Operational best practices emphasize multi‑node Raft quorum, TLS + mTLS, OPA‑based RBAC, journaling tune‑ables (sync interval, batch size), regular backups, and alerting on leader loss, DLQ growth, or latency spikes.
# - Future road‑map (2026‑2030) targets AI‑driven routing, zero‑trust SPIFFE identities, post‑quantum TLS, serverless edge functions, and full‑mesh multi‑cloud federation, cementing MCP as the go‑to backbone for real‑time, high‑throughput enterprise messaging.
# Failed to multipart ingest runs: Connection error caused failure to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. Please confirm your internet connection. SSLError(MaxRetryError("HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Max retries exceeded with url: /runs/multipart (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))"))
# Content-Length: 170335
# API Key: lsv2_********************************************7ftrace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef2-2406-7532-a238-5bd15b4e7b7d; trace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef2-240a-7803-b812-5a7717864e07; trace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef2-240e-7941-8d07-e6bd8d975787; trace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef1-0e32-7fd2-adb3-58d85124c9b8
# Failed to multipart ingest runs: Connection error caused failure to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. Please confirm your internet connection. SSLError(MaxRetryError("HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Max retries exceeded with url: /runs/multipart (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))"))
# Content-Length: 37182
# API Key: lsv2_********************************************7ftrace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef2-31a9-7ba3-ad67-ed7360c96b70; trace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2; trace=019f6ef1-0e31-7cf1-b699-7f6286b2d1d2,id=019f6ef2-240e-7941-8d07-e6bd8d975787

# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from Pydantic import BaseModel, Feild
model = ChatOllama(model="gpt-oss:120b-cloud")
 
class Person(BaseModel):
    name: str=Field(description = " full Name of the person")
    age: str=Feild(description= "the age of the person should be greater than 18")
    city: str=Feild(description="The city if the person in which he lives")
 
parser = PydanticOutputParser(pydantic_object=Person)
 
template = PromptTemplate.from_template(
    template = """
        Give me the name of the india origin person
   """
)
